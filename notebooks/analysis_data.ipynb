# %%
path = '../data/weather_data.json'
import pandas as pd
import json

# %%
with open(path) as f:
    
    data = json.load(f)

df = pd.json_normalize(data)
df.head
# Out:
# <bound method NDFrame.head of      name        lat        lon country      state local_names.he  \
# 0  Palmas -10.183785 -48.333642      BR  Tocantins           פלמס
#
#   local_names.ka local_names.lt local_names.pl local_names.pt  ...  \
# 0        პალმასი       Palmasas         Palmas         Palmas  ...
#
#   local_names.ko local_names.fa local_names.zh local_names.de local_names.bg  \
# 0           파우마스         پالماس           帕尔马斯         Palmas         Палмас
#
#   local_names.kk local_names.tg local_names.en local_names.hy local_names.ja
# 0         Палмас         Палмас         Palmas         Պալմաս           パルマス
#
# [1 rows x 28 columns]>

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 28 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            1 non-null      str
#  1   lat             1 non-null      float64
#  2   lon             1 non-null      float64
#  3   country         1 non-null      str
#  4   state           1 non-null      str
#  5   local_names.he  1 non-null      str
#  6   local_names.ka  1 non-null      str
#  7   local_names.lt  1 non-null      str
#  8   local_names.pl  1 non-null      str
#  9   local_names.pt  1 non-null      str
#  10  local_names.ar  1 non-null      str
#  11  local_names.be  1 non-null      str
#  12  local_names.uk  1 non-null      str
#  13  local_names.sr  1 non-null      str
#  14  local_names.mk  1 non-null      str
#  15  local_names.mr  1 non-null      str
#  16  local_names.ru  1 non-null      str
#  17  local_names.lv  1 non-null      str
# ...
